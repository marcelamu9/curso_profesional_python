# %%
def is_palindrome(string:str)-> bool:
    string = string.replace(" ","").lower()
    return string == string[::-1]

# %%
def run():
    print(is_palindrome('1000'))

# %%
if __name__ == '__main__':
    run()
# Out:
# False

# %%
is_palindrome('ana')
# Out:
# True

# %%
def esprimo(int: n)->bool:
    cantidad = 0
    if n <= 1: return False
    if n == 2: return True
 #   if n == 3: return True
    for i in range(2,n):
        print('esta recorriendo el numero ', i)
        modulo = n%i
        if modulo==0:
            print('no es primo')
            return False
    return True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [113], in <cell line: 1>()
# ----> 1 def esprimo(int: n)->bool:
#       2     cantidad = 0
#       3     if n <= 1: return False
#
# NameError: name 'n' is not defined

# %%
print(range(2,2))
# Out:
# range(2, 2)

# %%
# Out:
# esta recorriendo el numero  2
# esta recorriendo el numero  3
# esta recorriendo el numero  4
# esta recorriendo el numero  5
# esta recorriendo el numero  6
# esta recorriendo el numero  7
# esta recorriendo el numero  8
# esta recorriendo el numero  9
# esta recorriendo el numero  10
# esta recorriendo el numero  11
# esta recorriendo el numero  12
# esta recorriendo el numero  13
# esta recorriendo el numero  14
# esta recorriendo el numero  15
# esta recorriendo el numero  16
# esta recorriendo el numero  17
# esta recorriendo el numero  18
# esta recorriendo el numero  19
# esta recorriendo el numero  20
# esta recorriendo el numero  21
# esta recorriendo el numero  22
# esta recorriendo el numero  23
# esta recorriendo el numero  24
# esta recorriendo el numero  25
# esta recorriendo el numero  26
# esta recorriendo el numero  27
# esta recorriendo el numero  28
# esta recorriendo el numero  29
# esta recorriendo el numero  30
# esta recorriendo el numero  31
# ...

# %%
x = round(1,2)
x.is_integer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [100], in <cell line: 2>()
#       1 x = round(1,2)
# ----> 2 x.is_integer()
#
# AttributeError: 'int' object has no attribute 'is_integer'
